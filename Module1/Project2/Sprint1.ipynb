# %%
#Epic2
import pandas as pd
import numpy as np

red_wine = pd.read_csv('winequality-red.csv', sep=";")

# %%
#Epic3 - 1
rw = (red_wine)
display(rw.head(10) , rw.tail(10))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#Epic3 - 2
rw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#Epic3 - 2
rw.shape
# Out:
# (1599, 12)

# %%
#Epic3 - 3 
print(rw.isna().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Epic3 - 4
print(rw.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
ww = pd.read_csv("winequality-white.csv",sep=";")
print(ww.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
rw['quality_label'] = rw['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

## here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
rw['quality_label'] = pd.Categorical(rw['quality_label'],
categories=['low', 'medium', 'high'])

# %%
ww['quality_label'] = ww['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

my_order = ['low', 'medium', 'high']

ww['quality_label'] = pd.Categorical(ww['quality_label'],
categories=my_order, ordered = True)

#print(ww.head())

# %%
rw["color"] = "red"
ww["color"] = "white"
#print(ww.head())
comb = pd.concat([rw,ww], ignore_index=True)
print(comb.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label color
# 0      9.4        5           low   red
# ...

# %%
print(comb.tail())
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality quality_label  color
# ...

# %%
pd.concat([rw.describe(), ww.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
corr_matrix_rw = rw.corr()
print(corr_matrix_rw)
corr_matrix_ww = ww.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sn

fig, ax = plt.subplots(1, 2, figsize=(25,10))
ax[0].set_title("Red Wine")
ax[1].set_title("White Wine")
mask1 = np.triu(np.ones_like(corr_matrix_rw, dtype=bool))
mask2 = np.triu(np.ones_like(corr_matrix_ww, dtype=bool))
sn.heatmap(corr_matrix_rw, mask=mask1, annot=True, linewidths=.5, ax=ax[0])
sn.heatmap(corr_matrix_ww, mask=mask2, annot=True, linewidths=.5, ax=ax[1])

plt.show()

# %%
x= comb["color"].value_counts()["red"]
y= comb["color"].value_counts()["white"]
a=[x,y]
print(a)
z=["red","white"]
colors=sn.color_palette("bright")[0:5]
plt.pie(a,labels=z,colors=colors,autopct="%.0f%%")
plt.show()
# Out:
# [1599, 4898]

# %%
display(ww.info())
display(rw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
#  12  quality_label         4898 non-null   category
#  13  color                 4898 non-null   object
# ...

# %%
rw["quality_label"].unique()
# Out:
# ['low', 'medium', 'high']
# Categories (3, object): ['low', 'medium', 'high']

# %%
ww["quality_label"].unique()
# Out:
# ['medium', 'low', 'high']
# Categories (3, object): ['low' < 'medium' < 'high']

# %%
fig, (ax2, ax1) = plt.subplots(ncols=2,sharey="row", figsize=(10,5))
#fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))

ax1.hist(rw['quality_label'], bins=5, alpha=0.9, label='Red Wine', color='red',align='mid', rwidth=2)
ax2.hist(ww['quality_label'], bins=5, alpha=0.9, label='White Wine', color='gray',align='mid', rwidth=2)

ax1.set_facecolor('xkcd:white')
ax2.set_facecolor('xkcd:white')

ax1.set_xlabel('Quality', color='black', fontsize=14, fontweight='bold')
ax2.set_xlabel('Quality', color='black', fontsize=14, fontweight='bold')

#ax1.set_ylabel('Quantity', color='black', fontsize=14, fontweight='bold')
ax2.set_ylabel('Quantity', color='black', fontsize=14, fontweight='bold')

ax1.set_title('Quality of Red Wines', color='black', fontsize=16, backgroundcolor='white', fontweight='bold')
ax2.set_title('Quality of White Wines', color='black', fontsize=16, backgroundcolor='white', fontweight='bold')

ax1.legend()
ax2.legend()

# %%
fig, axs = plt.subplots(1, 2,sharey=True ,figsize=(10, 5))

sn.histplot(data=ww, x='quality_label', bins=6, alpha=0.9, color='gray', ax=axs[0])
axs[0].set_title("Quality of White Wines", fontsize=16)
axs[0].set_xlabel("Quality", fontsize=12)
axs[0].set_ylabel("Quantity", fontsize=12)

sn.histplot(data=rw, x='quality_label', bins=6, alpha=0.9, color='red', ax=axs[1])
axs[1].set_title("Quality of Red Wines", fontsize=16)
axs[1].set_xlabel("Quality", fontsize=12)
axs[1].set_ylabel("Quantity", fontsize=12)

#plt.tight_layout()

plt.show()

# %%
red_counts = rw['quality_label'].value_counts()

plt.figure(figsize=(5,5))

plt.rcParams.update({'font.size': 18})

red_counts.index = ['Medium Quality Wine', 'Low Quality Wine', 'High Quality Wine']

plt.pie(red_counts, labels=red_counts.index, autopct='%1.1f%%')
plt.title('Red Wine Quality Label Distribution')
plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(15, 7.5))

# Create first boxplot with wine alcohol content and quality for red wine
sn.boxplot(x='quality_label', y='alcohol', data=rw, ax=ax1)
ax1.set_title('RW Quality vs. Alcohol Content', fontsize=14)
ax1.set_xlabel('Wine Quality Label', fontsize=16)
ax1.set_ylabel('Alcohol Content', fontsize=16)

# Create second boxplot with wine sulfates and quality for red wine
sn.boxplot(x='quality_label', y='sulphates', data=ww, ax=ax2)
ax2.set_title('WW Quality vs. Sulfates ', fontsize=16)
ax2.set_xlabel('Wine Quality', fontsize=16)
ax2.set_ylabel('Sulfates', fontsize=16)

#create third boxplot with citric acid content and quality for red wine

sn.boxplot(x='quality_label', y='citric acid', data=rw, ax=ax3)

ax3.set_title('RW Quality vs. Citric Acid', fontsize=16)
ax3.set_xlabel('Wine Quality', fontsize=16)
ax3.set_ylabel('citric_acid', fontsize=16)

# Create fourth boxplot with volatile acidity and quality for red wine
sn.boxplot(x='quality_label', y='volatile acidity', data=rw, ax=ax4)

ax4.set_title('RW Quality vs. Volatile Acidity', fontsize=16)

ax4.set_xlabel('Wine Quality', fontsize=16)
ax4.set_ylabel('volatile_acidity', fontsize=16)

# Adjust the layout of the subplots
plt.tight_layout()

# Show the plots
plt.show()

# %%
rw.hist(bins=15, color='red', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.5, 2))

rt = plt.suptitle('Red Wine Univariate Plots', x=1.5, y=2.1, fontsize=15)

# %%
ww.hist(bins=15, color='red', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.5, 2))

rt = plt.suptitle('White Wine Univariate Plots', x=1.5, y=2.1, fontsize=15)

# %%
fig, axs = plt.subplots(1, 2, sharey=True ,figsize=(10, 5))
sn.histplot(data=rw, x='residual sugar', bins=20, alpha=0.5, color='red', ax=axs[0])
axs[0].set_title("RW Residual Sugar", fontsize=16)

axs[0].set_xlabel("Residual Sugar", fontsize=12)
axs[0].set_ylabel("Quantity", fontsize=12)

sn.histplot(data=ww, x='residual sugar', bins=20, alpha=0.5, color='white', ax=axs[1])
axs[1].set_title("WW Residual Sugar", fontsize=16)

axs[1].set_xlabel("Residual Sugar", fontsize=12)
axs[1].set_ylabel("Quantity", fontsize=12)

rt = plt.suptitle('Residual Sugar Content in Wine', fontsize=18)
plt.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(25,10))
ax[0].set_title("Red Wine")
ax[1].set_title("White Wine")
mask1 = np.triu(np.ones_like(corr_matrix_rw, dtype=bool))
mask2 = np.triu(np.ones_like(corr_matrix_ww, dtype=bool))
sn.heatmap(corr_matrix_rw, mask=mask1, annot=True, linewidths=.5, ax=ax[0], cmap="PiYG")
sn.heatmap(corr_matrix_ww, mask=mask2, annot=True, linewidths=.5, ax=ax[1], cmap="Blues")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sn.scatterplot(data=rw, x='density', y='pH', hue='quality_label', ax=ax)
ax.set_title('XXXX', fontsize=18)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 7))
sn.scatterplot(data=rw, x='density', y='pH', hue='quality_label', ax=ax)
#sn.scatterplot(data=rw, x='density', y='pH', ax=ax)
ax.set_title('Density vs pH in Red Wine Samples', fontsize=18)
plt.show()

# %%
fig, axs = plt.subplots(figsize=(7, 7))
red_high = rw.query("quality_label == 'high'")
sn.scatterplot(data= red_high , x='density', y='pH', hue='quality_label', ax=axs)
axs.set_title('Density vs pH for High Quality Red Wine Samples', fontsize=18)
z_red = np.polyfit(red_high['density'], red_high['pH'], 1)
p_red = np.poly1d(z_red)
axs.plot(red_high['density'], p_red(red_high['density']), "r--")

# %%
fig, axs = plt.subplots(figsize=(7, 7))
red_high = rw.query("quality_label == 'high'")
sn.scatterplot(data= red_high , x='alcohol', y='pH', hue='quality_label', ax=axs)
axs.set_title('Alcohol Content vs pH for High Quality Red Wine Samples', fontsize=18)
z_red = np.polyfit(red_high['alcohol'], red_high['pH'], 1)
p_red = np.poly1d(z_red)
axs.plot(red_high['alcohol'], p_red(red_high['alcohol']), "r--")

# %%
#presentation prep
sn.histplot(data=rw, x="quality", y="alcohol")
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
g=sn.jointplot(data=rw, x="quality", y="alcohol")
rt = plt.suptitle('Red Wines Alcohol - Quality', fontsize=12)
g.plot_joint(sn.kdeplot, color="r", zorder=0, levels=10)
g.plot_marginals(sn.rugplot, color="r", height=-.15, clip_on=False)

# %%
#fig, ax = plt.subplots(figsize=(10, 10))
sn.lmplot(data=rw, x='fixed acidity', y='pH', hue='quality_label', height=7)
#ax.set_title('Fixed acidity vs pH for RW', fontsize=18)
plt.show()

# %%
g=sn.jointplot(data=rw, x="quality", y="sulphates")
rt = plt.suptitle('Red Wines Sulphates - Quality', fontsize=12)
g.plot_joint(sn.kdeplot, color="r", zorder=0, levels=10)
g.plot_marginals(sn.rugplot, color="r", height=-.15, clip_on=False)

# %%
g=sn.jointplot(data=ww, x="quality", y="sulphates")
rt = plt.suptitle('Red Wines Sulphates - Quality', fontsize=12)
g.plot_joint(sn.kdeplot, color="r", zorder=0, levels=10)
g.plot_marginals(sn.rugplot, color="r", height=-.15, clip_on=False)

# %%
fig, ax = plt.subplots(figsize=(7, 7))
sn.scatterplot(data=rw, x='alcohol', y='pH', hue='quality_label', ax=ax)
ax.set_title('Alcohol vs pH for RW', fontsize=18)
plt.show()

# %%
from scipy import stats

F, p = stats.f_oneway(rw[rw['quality_label'] == 'low']['alcohol'],
rw[rw['quality_label'] == 'medium']['alcohol'],
rw[rw['quality_label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 205.23448800361507 	p-value: 4.776936653588672e-80

# %%
F, p = stats.f_oneway(rw[rw['quality_label'] == 'low']['pH'],
rw[rw['quality_label'] == 'medium']['pH'],
rw[rw['quality_label'] == 'high']['pH'])
print('F Statistic:', F, '\tp-value:', p)
# Out:
# F Statistic: 0.7354879827479522 	p-value: 0.4794338960102369

# %%
means = pd.read_csv('means.csv', sep=",")
#means = pd.read_csv('means.csv', sep=",", usecols = ["residual sugar","sulphates","total sulfur dioxide","pH","type","density", "volatile acidity", "alcohol","quality"])
#means=means.groupby(["type"]).sum

print(means)
# Out:
#   type fixed acidity volatile acidity citric acid residual sugar chlorides  \
# 0   rw      8,319637         0,527821    0,270976       2,538806  0,087467
# 1   ww      6,854788         0,278241    0,334192       6,391415  0,045772
#
#   free sulfur dioxide total sulfur dioxide   density        pH sulphates  \
# 0           15,874922            46,467792  0,996747  3,311113  0,658149
# 1           35,308085           138,360657  0,994027  3,188267  0,489847
#
#      alcohol   quality
# 0  10,422983  5,636023
# 1  10,514267  5,877909

# %%
#Spider chart for rw & ww
labels=np.array(["type","density", "pH", "alcohol","quality"])
stats=means.loc[1,labels].values

angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))

fig=sn.plt.figure()
ax = fig.add_subplot(111, polar=True)
ax.plot(angles, stats, 'o-', linewidth=2)
ax.fill(angles, stats, alpha=0.25)
ax.set_thetagrids(angles * 180/np.pi, labels)
ax.set_title([df.loc[386,"Name"]])
ax.grid(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-6cc07b631c1c> in <module>
#       8 angles=np.concatenate((angles,[angles[0]]))
#       9
# ---> 10 fig=sn.plt.figure()
#      11 ax = fig.add_subplot(111, polar=True)
#      12 ax.plot(angles, stats, 'o-', linewidth=2)
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
import plotly.express as px
means2=pd.read_csv("means2.csv")
fig = px.line_polar(means2, r = 'value', theta = 'variable', line_close = True,
                    color = 'type')
fig.update_traces(fill = 'toself')

fig.show()

# %%
print(comb['quality'].astype(float).skew())
# Out:
# 0.18962269337269683

# %%
print(comb['quality'].astype(float).kurt())
# Out:
# 0.2323222693432636

# %%
# ENCODING WINE COLOR
# Get one hot encoding of columns Type
encoded = pd.get_dummies(comb['color'])
encoded
# replace type column with the two encoded columns
comb = pd.concat([comb, encoded], axis=1)
# drop the original type column (axis=1 refers to the columns)
comb = comb.drop('color', axis=1)
# print the first five rows of the data 
display(comb.head())
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality quality_label  red  white
# ...

# %%
# ENCODING WINE QUALITY
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
comb["quality_label"]=le.fit_transform(comb["quality_label"])
display(comb.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  quality_label  red  white
# ...

# %%
display(comb.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality_label  red  white
# 0      9.4              1    1      0
# ...

# %%
# Splitting Data
from sklearn.model_selection import train_test_split

y = comb["quality_label"]
X = comb.drop(["quality_label"],axis=1)
display(y.head())
display(X.head())
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    1
# Name: quality_label, dtype: int32
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
# ...

# %%
# Splitting data into testing & training sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=42, stratify=y)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (5197, 13) (1300, 13)
# (5197,) (1300,)
