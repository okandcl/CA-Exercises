# %%
import numpy as np
import pandas as pd

df=pd.read_csv("movies_2.csv") #gathering data
df.head(5)
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
df.shape
# Out:
# (616, 11)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       616 non-null    int64
#  1   Title         615 non-null    object
#  2   MPAA Rating   615 non-null    object
#  3   Budget        615 non-null    float64
#  4   Gross         615 non-null    float64
#  5   Release Date  615 non-null    object
#  6   Genre         615 non-null    object
#  7   Runtime       615 non-null    float64
#  8   Rating        508 non-null    float64
#  9   Rating Count  508 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 53.1+ KB
# None

# %%
print(df.dtypes)
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
df.describe()
# Out:
#           MovieID        Budget         Gross     Runtime      Rating  \
# count  616.000000  6.150000e+02  6.150000e+02  615.000000  508.000000
# mean   307.500000  9.491710e+07  4.453221e+08  118.642276    6.917323
# std    177.968162  6.748114e+07  3.394075e+08   22.252376    0.888928
# min      0.000000  6.000000e+04  5.300000e+07   79.000000    4.100000
# 25%    153.750000  4.000000e+07  2.158939e+08  102.000000    6.400000
# 50%    307.500000  8.000000e+07  3.510404e+08  117.000000    6.900000
# 75%    461.250000  1.400000e+08  5.851766e+08  132.000000    7.600000
# max    615.000000  4.000000e+08  2.796000e+09  201.000000    9.000000
#
#        Rating Count
# count  5.080000e+02
# mean   3.392521e+05
# std    3.213388e+05
# min    1.491800e+04
# 25%    1.275922e+05
# 50%    2.403475e+05
# 75%    4.257000e+05
# max    2.127228e+06

# %%
df.drop("Summary", axis=1)
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
df=df.rename(str.lower, axis=1) 
df.columns=df.columns.str.replace(" ","_")
df.head()
# Out:
#    movieid                       title mpaa_rating      budget        gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   release_date    genre  runtime  rating  rating_count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
df.drop(615)
# Out:
#      movieid                                  title mpaa_rating       budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %%
df["Rating"].fillna(value=df["Rating"].median(), inplace=True)
df.sort_values(by='Rating', ascending=True)
# Out:
#      MovieID                                          Title MPAA Rating  \
# 426      427                             The Last Airbender          PG
# 278      279                        Spy Kids 3-D: Game Over          PG
# 413      414                                           2012       PG-13
# 438      439           Alvin and the Chipmunks: Chipwrecked           G
# 227      228                 Nutty Professor II: The Klumps       PG-13
# ..       ...                                            ...         ...
# 287      288  The Lord of the Rings: The Return of the King       PG-13
# 99       100                                   Pulp Fiction           R
# 98        99                              Jurassic Park III       PG-13
# 83        84                               Schindler's List           R
# 393      394                                The Dark Knight       PG-13
#
#           Budget         Gross Release Date      Genre  Runtime  Rating  \
# ...

# %%
df["Rating Count"].fillna(value=df["Rating Count"].median(), inplace=True)
df.sort_values(by='Rating Count', ascending=True)
# Out:
#      MovieID                Title MPAA Rating       Budget         Gross  \
# 51        52  The Prince of Tides           R   30000000.0  7.478760e+07
# 181      182    The Rugrats Movie           G   30000000.0  1.004917e+08
# 121      122     Grumpier Old Men       PG-13   25000000.0  7.150000e+07
# 71        72            Boomerang           R   40000000.0  7.010000e+07
# 413      414                 2012       PG-13  200000000.0  7.696536e+08
# ..       ...                  ...         ...          ...           ...
# 98        99    Jurassic Park III       PG-13   93000000.0  3.688000e+08
# 99       100         Pulp Fiction           R    8000000.0  2.139288e+08
# 403      404     Fast and Furious       PG-13   85000000.0  3.632000e+08
# 427      428            Inception       PG-13  160000000.0  8.255328e+08
# 393      394      The Dark Knight       PG-13  185000000.0  1.004558e+09
#
#     Release Date      Genre  Runtime  Rating  Rating Count  \
# ...

# %%
df.drop_duplicates(subset=['Title'])
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
df.astype({'Budget': 'int64'}).dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-06422c70f3de> in <module>
# ----> 1 df.astype({'Budget': 'int32'}).dtypes
#
# c:\Users\asus\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5860                 if col_name in dtype:
#    5861                     results.append(
# -> 5862                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5863                     )
#    5864                 else:
#
# c:\Users\asus\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       616 non-null    int64
#  1   Title         615 non-null    object
#  2   MPAA Rating   615 non-null    object
#  3   Budget        615 non-null    float64
#  4   Gross         615 non-null    float64
#  5   Release Date  615 non-null    object
#  6   Genre         615 non-null    object
#  7   Runtime       615 non-null    float64
#  8   Rating        508 non-null    float64
#  9   Rating Count  508 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 53.1+ KB

# %%
df.isnull().count()
# Out:
# MovieID         616
# Title           616
# MPAA Rating     616
# Budget          616
# Gross           616
# Release Date    616
# Genre           616
# Runtime         616
# Rating          616
# Rating Count    616
# Summary         616
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 496 entries, 0 to 509
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       496 non-null    int64
#  1   Title         496 non-null    object
#  2   MPAA Rating   496 non-null    object
#  3   Budget        496 non-null    float64
#  4   Gross         496 non-null    float64
#  5   Release Date  496 non-null    object
#  6   Genre         496 non-null    object
#  7   Runtime       496 non-null    float64
#  8   Rating        496 non-null    float64
#  9   Rating Count  496 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 46.5+ KB

# %%
df['Gross'] = df['Gross'].astype(int)
# Out:
# <ipython-input-137-efaad2ae65aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gross'] = df['Gross'].astype(int)

# %%
df.astype({'Budget': 'int64'}).dtypes
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget            int64
# Gross             int32
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
df["Release Date"]=pd.to_datetime(df["Release Date"])
display(df.dtypes)
# Out:
# MovieID                  int64
# Title                   object
# MPAA Rating             object
# Budget                 float64
# Gross                  float64
# Release Date    datetime64[ns]
# Genre                   object
# Runtime                float64
# Rating                 float64
# Rating Count           float64
# Summary                 object
# dtype: object

# %%
df[(df["Rating"]>7) & (df["Gross"]> 50000000)]
# Out:
#      MovieID                                Title MPAA Rating       Budget  \
# 1          2                   Driving Miss Daisy          PG    7500000.0
# 2          3                       Turner & Hooch          PG   13000000.0
# 3          4           Born on the Fourth of July           R   14000000.0
# 4          5                      Field of Dreams          PG   15000000.0
# 6          7              When Harry Met Sally...           R   16000000.0
# ..       ...                                  ...         ...          ...
# 505      506                           Big Hero 6          PG  165000000.0
# 506      507                         Interstellar       PG-13  165000000.0
# 507      508  Captain America: The Winter Soldier       PG-13  170000000.0
# 508      509       Dawn of the Planet of the Apes       PG-13  170000000.0
# 509      510              Guardians of the Galaxy       PG-13  170000000.0
#
# ...

# %%
df[(df["Rating"]>7) & (df["Gross"]> 50000000) & (df["MPAA Rating"]=="PG")]
# Out:
#      MovieID                                     Title MPAA Rating  \
# 1          2                        Driving Miss Daisy          PG
# 2          3                            Turner & Hooch          PG
# 4          5                           Field of Dreams          PG
# 7          8                        Dead Poets Society          PG
# 13        14                                    Batman          PG
# 15        16                        The Little Mermaid          PG
# 16        17                Back to the Future Part II          PG
# 19        20                           Steel Magnolias          PG
# 24        25                                Home Alone          PG
# 32        33                  The Hunt for Red October          PG
# 34        35               Back to the Future Part III          PG
# 45        46           Teenage Mutant Ninja Turtles II          PG
# 46        47                      Beauty and the Beast          PG
# ...

# %%
df[(df["Genre"]=="Animation") & (df["Rating"]>7)].shape
# Out:
# (39, 11)

# %%
df.sort_values(by=["Budget"], ascending=False).head(5)
# Out:
#      MovieID                                        Title MPAA Rating  \
# 594      595                       Avengers: Infinity War       PG-13
# 454      455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614      615                            Avengers: Endgame       PG-13
# 574      575                     Star Wars: The Last Jedi       PG-13
# 375      376     Pirates of the Caribbean: At World's End       PG-13
#
#           Budget         Gross Release Date            Genre  Runtime  Rating  \
# 594  400000000.0  2.048000e+09   2018-04-23           Action    149.0     NaN
# 454  380000000.0  1.045714e+09   2011-05-14           Action    136.0     6.6
# 614  356000000.0  2.796000e+09   2019-04-22           Action    181.0     NaN
# 574  317000000.0  1.333000e+09   2019-12-09  Science Fiction    152.0     NaN
# 375  300000000.0  9.610000e+08   2007-05-19        Adventure    169.0     7.1
#
#      Rating Count                                            Summary
# ...

# %%
df[(df["Genre"]=="Comedy")].sort_values(by=["Rating"], ascending=False).head(5)
# Out:
#      MovieID                   Title MPAA Rating       Budget        Gross  \
# 111      112            Forrest Gump       PG-13   55000000.0  677945399.0
# 185      186         The Truman Show          PG   60000000.0  264118201.0
# 80        81           Groundhog Day          PG   14600000.0   70906973.0
# 254      255          Monsters, Inc.           G  115000000.0  562816256.0
# 316      317  The 40 Year Old Virgin           R   26000000.0  109449237.0
#
#     Release Date   Genre  Runtime  Rating  Rating Count  \
# 111   1994-07-06  Comedy    142.0     8.8     1657851.0
# 185   1998-06-04  Comedy    103.0     8.1      859224.0
# 80    1993-02-11  Comedy    101.0     8.0      549538.0
# 254   2001-11-01  Comedy     92.0     8.0      758349.0
# 316   2005-08-11  Comedy    116.0     7.7      500448.0
#
#                                                Summary
# 111  The presidencies of Kennedy and Johnson, the e...
# 185  An insurance salesman discovers his whole life...
# ...

# %%
df.sort_values(by=["Rating"], ascending=False).head(5)["Title"]
# Out:
# 393                                  The Dark Knight
# 98                                 Jurassic Park III
# 287    The Lord of the Rings: The Return of the King
# 99                                      Pulp Fiction
# 83                                  Schindler's List
# Name: Title, dtype: object

# %%
df[(df["Genre"]=="Romance") & (df["Release Date"]>="2000-01-01")].sort_values(by=["Gross"], ascending=False).head(3)
# Out:
#      MovieID                                      Title MPAA Rating  \
# 464      465  The Twilight Saga: Breaking Dawn - Part 2       PG-13
# 442      443  The Twilight Saga: Breaking Dawn - Part 1       PG-13
# 401      402                The Twilight Saga: New Moon       PG-13
#
#           Budget        Gross Release Date    Genre  Runtime  Rating  \
# 464  120000000.0  829000000.0   2012-11-13  Romance    115.0     5.5
# 442  110000000.0  712171856.0   2011-03-15  Romance    117.0     4.9
# 401   50000000.0  709827462.0   2009-03-15  Romance    130.0     4.7
#
#      Rating Count                                            Summary
# 464      218357.0  After the birth of Renesmee/Nessie, the Cullen...
# 442      211592.0  The Quileutes close in on expecting parents Ed...
# 401      252223.0  Edward leaves Bella after an attack that nearl...

# %%
df.Genre.value_counts()
# Out:
# Action             110
# Comedy              99
# Animation           87
# Drama               66
# Thriller            41
# Science Fiction     37
# Adventure           30
# Family              29
# Romance             28
# Fantasy             27
# Crime               17
# Horror              14
# Mystery             11
# War                  9
# Western              6
# History              4
# Name: Genre, dtype: int64
