# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import datetime as dt

# %%
day = pd.read_csv("day.csv")
hour = pd.read_csv("hour.csv")

# %%
display(day.head()) 
display(day.tail())
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
# ...

# %%
display(hour.head(1800)) 
display(hour.tail())
# Out:
#       instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0           1  2011-01-01       1   0     1   0        0        6           0
# 1           2  2011-01-01       1   0     1   1        0        6           0
# 2           3  2011-01-01       1   0     1   2        0        6           0
# 3           4  2011-01-01       1   0     1   3        0        6           0
# 4           5  2011-01-01       1   0     1   4        0        6           0
# ...       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 1795     1796  2011-03-20       1   0     3  12        0        0           0
# 1796     1797  2011-03-20       1   0     3  13        0        0           0
# 1797     1798  2011-03-20       1   0     3  14        0        0           0
# 1798     1799  2011-03-20       1   0     3  15        0        0           0
# 1799     1800  2011-03-20       1   0     3  16        0        0           0
#
# ...

# %%
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
day.shape
# Out:
# (731, 16)

# %%
hour.shape
# Out:
# (17379, 17)

# %%
# Cont. /w hour df since it has more details
df=hour.copy()

# %%
df.nunique()
# Out:
# instant       17379
# dteday          731
# season            4
# yr                2
# mnth             12
# hr               24
# holiday           2
# weekday           7
# workingday        2
# weathersit        4
# temp             50
# atemp            65
# hum              89
# windspeed        30
# casual          322
# registered      776
# cnt             869
# dtype: int64

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.describe(include="all").T
# Out:
#               count unique         top freq        mean         std   min  \
# instant     17379.0    NaN         NaN  NaN      8690.0   5017.0295   1.0
# dteday        17379    731  2011-11-16   24         NaN         NaN   NaN
# season      17379.0    NaN         NaN  NaN     2.50164    1.106918   1.0
# yr          17379.0    NaN         NaN  NaN    0.502561    0.500008   0.0
# mnth        17379.0    NaN         NaN  NaN    6.537775    3.438776   1.0
# hr          17379.0    NaN         NaN  NaN   11.546752    6.914405   0.0
# holiday     17379.0    NaN         NaN  NaN     0.02877    0.167165   0.0
# weekday     17379.0    NaN         NaN  NaN    3.003683    2.005771   0.0
# workingday  17379.0    NaN         NaN  NaN    0.682721    0.465431   0.0
# weathersit  17379.0    NaN         NaN  NaN    1.425283    0.639357   1.0
# temp        17379.0    NaN         NaN  NaN    0.496987    0.192556  0.02
# atemp       17379.0    NaN         NaN  NaN    0.475775     0.17185   0.0
# ...

# %%
df["dteday"] = pd.to_datetime(df["dteday"])
print(df.dtypes)
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
df.loc[df['holiday'] == 0, 'holiday'] = 'No'
df.loc[df['holiday'] == 1, 'holiday'] = 'Yes'

# %%
df.loc[df['season'] == 1, 'season'] = 'Winter'
df.loc[df['season'] == 2, 'season'] = 'Spring'
df.loc[df['season'] == 3, 'season'] = 'Summer'
df.loc[df['season'] == 4, 'season'] = 'Fall'

# %%
df.loc[df['weathersit'] == 1, 'weather'] = 'Clear'
df.loc[df['weathersit'] == 2, 'weather'] = 'Cloudy'
df.loc[df['weathersit'] == 3, 'weather'] = 'Light_Rain'
df.loc[df['weathersit'] == 4, 'weather'] = 'Heavy_Rain'

# %%
df.loc[df['weekday'] == 0, 'weekday'] = 'Sunday'
df.loc[df['weekday'] == 1, 'weekday'] = 'Monday'
df.loc[df['weekday'] == 2, 'weekday'] = 'Tuesday'
df.loc[df['weekday'] == 3, 'weekday'] = 'Wednesday'
df.loc[df['weekday'] == 4, 'weekday'] = 'Thursday'
df.loc[df['weekday'] == 5, 'weekday'] = 'Friday'
df.loc[df['weekday'] == 6, 'weekday'] = 'Saturday'

# %%
df.loc[df['yr'] == 0, 'yr'] = '2011'
df.loc[df['yr'] == 1, 'yr'] = '2012'

# %%
df["temp"] = (df["temp"]*47)-8

# %%
df["atemp"] = (df["atemp"]*66)-16

# %%
df["hum"] = df["hum"]*100

# %%
df["windspeed"] = df["windspeed"]*67

# %%
display(df.head())
# Out:
#    instant     dteday  season    yr  mnth  hr holiday   weekday  workingday  \
# 0        1 2011-01-01  Winter  2011     1   0      No  Saturday           0
# 1        2 2011-01-01  Winter  2011     1   1      No  Saturday           0
# 2        3 2011-01-01  Winter  2011     1   2      No  Saturday           0
# 3        4 2011-01-01  Winter  2011     1   3      No  Saturday           0
# 4        5 2011-01-01  Winter  2011     1   4      No  Saturday           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt weather
# 0           1  3.28  3.0014  81.0        0.0       3          13   16   Clear
# 1           1  2.34  1.9982  80.0        0.0       8          32   40   Clear
# 2           1  2.34  1.9982  80.0        0.0       5          27   32   Clear
# 3           1  3.28  3.0014  75.0        0.0       3          10   13   Clear
# 4           1  3.28  3.0014  75.0        0.0       0           1    1   Clear

# %%
df.describe()
# Out:
#           instant          mnth            hr    workingday    weathersit  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      6.537775     11.546752      0.682721      1.425283
# std     5017.0295      3.438776      6.914405      0.465431      0.639357
# min        1.0000      1.000000      0.000000      0.000000      1.000000
# 25%     4345.5000      4.000000      6.000000      0.000000      1.000000
# 50%     8690.0000      7.000000     12.000000      1.000000      1.000000
# 75%    13034.5000     10.000000     18.000000      1.000000      2.000000
# max    17379.0000     12.000000     23.000000      1.000000      4.000000
#
#                temp         atemp           hum     windspeed        casual  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean      15.358397     15.401157     62.722884     12.736540     35.676218
# ...

# %%
df["yr"] = df["yr"].astype('category')
df["mnth"] = df["mnth"].astype('category')
df["holiday"] = df["holiday"].astype('category')
df["weekday"] = df["weekday"].astype('category')
df["workingday"] = df["workingday"].astype('category')
df["weathersit"] = df["weathersit"].astype('category')
df["season"] = df["season"].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  category
#  3   yr          17379 non-null  category
#  4   mnth        17379 non-null  category
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  category
#  7   weekday     17379 non-null  category
#  8   workingday  17379 non-null  category
#  9   weathersit  17379 non-null  category
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
#  17  weather     17379 non-null  object
# ...

# %%
for i in df.index:
    if df["temp"][i] <= 15:
        df["temp"][i] = "Cold"
    elif df["temp"][i]>15 and df["temp"][i] <= 20:
        df["temp"][i] = "Cool"
    elif df["temp"][i]>20 and df["temp"][i] <= 25:
        df["temp"][i] = "Warm"
    elif df["temp"][i]>25 and df["temp"][i] <= 30:
        df["temp"][i] = "Hot"
    elif df["temp"][i]>30 and df["temp"][i] <= 35:
        df["temp"][i] = "Very_Hot"
    else:
        df["temp"][i] ="Xtrm_Hot"
# Out:
# <ipython-input-34-31e7001011d3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["temp"][i] = "Cold"
# c:\Users\asus\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-34-31e7001011d3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["temp"][i] = "Cool"
# ...

# %%
display(df.tail(3000))
# Out:
#        instant     dteday  season    yr mnth  hr holiday weekday workingday  \
# 14379    14380 2012-08-27  Summer  2012    8   8      No  Monday          1
# 14380    14381 2012-08-27  Summer  2012    8   9      No  Monday          1
# 14381    14382 2012-08-27  Summer  2012    8  10      No  Monday          1
# 14382    14383 2012-08-27  Summer  2012    8  11      No  Monday          1
# 14383    14384 2012-08-27  Summer  2012    8  12      No  Monday          1
# ...        ...        ...     ...   ...  ...  ..     ...     ...        ...
# 17374    17375 2012-12-31  Winter  2012   12  19      No  Monday          1
# 17375    17376 2012-12-31  Winter  2012   12  20      No  Monday          1
# 17376    17377 2012-12-31  Winter  2012   12  21      No  Monday          1
# 17377    17378 2012-12-31  Winter  2012   12  22      No  Monday          1
# 17378    17379 2012-12-31  Winter  2012   12  23      No  Monday          1
#
# ...

# %%
df["temp"] = df["temp"].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  category
#  3   yr          17379 non-null  category
#  4   mnth        17379 non-null  category
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  category
#  7   weekday     17379 non-null  category
#  8   workingday  17379 non-null  category
#  9   weathersit  17379 non-null  category
#  10  temp        17379 non-null  category
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
#  17  weather     17379 non-null  object
# ...

# %%
for i in df.index:
    if df["windspeed"][i] <= 5:
        df["windspeed"][i] = "Calm"
    elif df["windspeed"][i]>5 and df["windspeed"][i] <= 25:
        df["windspeed"][i] = "Light"
    elif df["windspeed"][i]>25 and df["windspeed"][i] <= 40:
        df["windspeed"][i] = "Breezy"
    elif df["windspeed"][i]>40 and df["windspeed"][i] <= 50:
        df["windspeed"][i] = "Windy"
    else:
        df["windspeed"][i] ="Very Windy"
# Out:
# <ipython-input-37-6849bfc910b2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["windspeed"][i] = "Calm"
# c:\Users\asus\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-37-6849bfc910b2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["windspeed"][i] = "Light"
# ...

# %%
display(df.tail(3000))
# Out:
#        instant     dteday  season    yr mnth  hr holiday weekday workingday  \
# 14379    14380 2012-08-27  Summer  2012    8   8      No  Monday          1
# 14380    14381 2012-08-27  Summer  2012    8   9      No  Monday          1
# 14381    14382 2012-08-27  Summer  2012    8  10      No  Monday          1
# 14382    14383 2012-08-27  Summer  2012    8  11      No  Monday          1
# 14383    14384 2012-08-27  Summer  2012    8  12      No  Monday          1
# ...        ...        ...     ...   ...  ...  ..     ...     ...        ...
# 17374    17375 2012-12-31  Winter  2012   12  19      No  Monday          1
# 17375    17376 2012-12-31  Winter  2012   12  20      No  Monday          1
# 17376    17377 2012-12-31  Winter  2012   12  21      No  Monday          1
# 17377    17378 2012-12-31  Winter  2012   12  22      No  Monday          1
# 17378    17379 2012-12-31  Winter  2012   12  23      No  Monday          1
#
# ...

# %%
df["windspeed"] = df["windspeed"].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  category
#  3   yr          17379 non-null  category
#  4   mnth        17379 non-null  category
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  category
#  7   weekday     17379 non-null  category
#  8   workingday  17379 non-null  category
#  9   weathersit  17379 non-null  category
#  10  temp        17379 non-null  category
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  category
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
#  17  weather     17379 non-null  object
# ...

# %%
sn.set_style('whitegrid')
sn.set_context('talk')
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (30, 10),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'}

plt.rcParams.update(params)

# %%
fig,ax = plt.subplots()
sn.pointplot(data=df[['hr', 'cnt', 'season']],
              x='hr',
              y='cnt',
              hue='season',
              ax=ax)
ax.set(title="Season wise hourly distribution of counts")
# Out:
# [Text(0.5, 1.0, 'Season wise hourly distribution of counts')]

# %%
fig,ax = plt.subplots()
sn.pointplot(data=df[['mnth', 'cnt', 'yr']],
              x='mnth',
              y='cnt',
              hue='yr',
              ax=ax)
ax.set(title="Year wise monthly distribution of counts")
# Out:
# [Text(0.5, 1.0, 'Year wise monthly distribution of counts')]

# %%
fig,ax = plt.subplots()
ho = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
sn.pointplot(data=df[['hr',
                           'cnt',
                           'weekday']],
              x='hr',
              y='cnt',
              hue='weekday',
              ax=ax,
              hue_order=ho)
ax.set(title="Weekday wise hourly distribution of counts")
# Out:
# [Text(0.5, 1.0, 'Weekday wise hourly distribution of counts')]

# %%
fig,axs = plt.subplots(1, 2, sharey="row")
ho = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
sn.lineplot(data=df[['casual', 'hr', 'weekday']],
              x= 'hr',
              y='casual',
              hue='weekday',
              ax=axs[0], hue_order=ho)
sn.lineplot(data=df[['registered', 'hr', 'weekday']],
              x= 'hr',
              y='registered',
              hue='weekday', legend=False,
              ax=axs[1], hue_order=ho)
axs[1].set_ylabel("registered")
plt.show()

# %%
fig,axs = plt.subplots(1, 2, sharey="row")
sn.lineplot(data=df[['casual', 'hr', 'season']],
              x= 'hr',
              y='casual',
              hue='season',
              ax=axs[0])
sn.lineplot(data=df[['registered', 'hr', 'season']],
              x= 'hr',
              y='registered',
              hue='season', legend=False,
              ax=axs[1])
axs[1].set_ylabel("registered")
plt.show()

# %%
fig,ax = plt.subplots()
ho = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
sn.pointplot(data=df[['hr',
                           'registered',
                           'weekday']],
              x='hr',
              y='registered',
              hue='weekday',
              ax=ax,
              hue_order=ho)
ax.set(title="regs")
# Out:
# [Text(0.5, 1.0, 'regs')]

# %%
fig,ax = plt.subplots()
sn.pointplot(data=df[['hr',
                           'cnt',
                           'holiday']],
              x='hr',
              y='cnt',
              hue='holiday',
              ax=ax)
ax.set(title="regs")
# Out:
# [Text(0.5, 1.0, 'regs')]

# %%
fig,axs = plt.subplots(1, 2, sharey="row")
sn.lineplot(data=df[['casual', 'hr', 'holiday']],
              x= 'hr',
              y='casual',
              hue='holiday',
              ax=axs[0])
sn.lineplot(data=df[['registered', 'hr', 'holiday']],
              x= 'hr',
              y='registered',
              hue='holiday', legend=False,
              ax=axs[1])
axs[1].set_ylabel("registered")
plt.show()

# %%
answers = df.groupby("yr", as_index = False).sum()
print(answers)
# Out:
#      yr    instant      hr        atemp       hum  casual  registered      cnt
# 0  2011   37372335  100054  129277.5874  556245.0  247252      995851  1243103
# 1  2012  113651175  100617  138379.1156  533816.0  372765     1676811  2049576

# %%
answers2 = df["casual"].sum()
print(answers2)
# Out:
# 620017

# %%
fig,ax = plt.subplots(figsize=(12,10))
sn.barplot(data=answers[['yr', 'cnt']],
              x='yr',
              y='cnt',
              ax=ax)
ax.set(title="distribution of counts according to year")
# Out:
# [Text(0.5, 1.0, 'distribution of counts according to year')]

# %%
ans = df.groupby(["yr", "mnth"], as_index = False).sum()
print(ans)
# Out:
#       yr mnth   instant    hr       atemp      hum  casual  registered     cnt
# 0   2011    1    237016  8168  -1755.7636  39495.0    3073       35116   38189
# 1   2011    2    657437  7649   1854.9410  36325.0    6242       41973   48215
# 2   2011    3   1242825  8506   3972.6788  41614.0   12826       51219   64045
# 3   2011    4   1745013  8277  10164.6382  48045.0   22346       72524   94870
# 4   2011    5   2349924  8556  15143.1498  53074.0   31050      104771  135821
# 5   2011    6   2801160  8280  19204.5048  42714.0   30612      112900  143512
# 6   2011    7   3439140  8556  22992.2592  43871.0   36452      104889  141341
# 7   2011    8   3918160  8412  19936.4668  45733.0   28842      107849  136691
# 8   2011    9   4362228  8274  15434.8668  56200.0   26545      100873  127418
# 9   2011   10   5062802  8553  10605.8296  52496.0   25222       98289  123511
# 10  2011   11   5424855  8278   7439.4586  48548.0   15594       86573  102167
# ...

# %%
fig,ax = plt.subplots()
sn.barplot(data=ans[['mnth',
                           'cnt',
                           'yr']],
              x='mnth',
              y='cnt',
              hue='yr',
              ax=ax)
ax.set(title="count over months")
# Out:
# [Text(0.5, 1.0, 'count over months')]

# %%
fig,ax = plt.subplots()
sn.barplot(data=df[['mnth', 'cnt']],
              x='mnth',
              y='cnt',
              ax=ax)
ax.set(title="Monthly distribution of counts")
# Out:
# [Text(0.5, 1.0, 'Monthly distribution of counts')]

# %%
fig,ax = plt.subplots(figsize=(12,10))
sn.barplot(data=df[['weather', 'cnt']],
              x='weather',
              y='cnt',
              ax=ax)
ax.set(title="weather condition counts")
# Out:
# [Text(0.5, 1.0, 'weather condition counts')]

# %%
corr_matrix = hour.corr()
print(corr_matrix)
# Out:
#              instant    season        yr      mnth        hr   holiday  \
# instant     1.000000  0.404046  0.866014  0.489164 -0.004775  0.014723
# season      0.404046  1.000000 -0.010742  0.830386 -0.006117 -0.009585
# yr          0.866014 -0.010742  1.000000 -0.010473 -0.003867  0.006692
# mnth        0.489164  0.830386 -0.010473  1.000000 -0.005772  0.018430
# hr         -0.004775 -0.006117 -0.003867 -0.005772  1.000000  0.000479
# holiday     0.014723 -0.009585  0.006692  0.018430  0.000479  1.000000
# weekday     0.001357 -0.002335 -0.004485  0.010400 -0.003498 -0.102088
# workingday -0.003416  0.013743 -0.002196 -0.003477  0.002285 -0.252471
# weathersit -0.014198 -0.014524 -0.019157  0.005400 -0.020203 -0.017036
# temp        0.136178  0.312025  0.040913  0.201691  0.137603 -0.027340
# atemp       0.137615  0.319380  0.039222  0.208096  0.133750 -0.030973
# hum         0.009577  0.150625 -0.083546  0.164411 -0.276498 -0.010588
# ...

# %%
fig, ax = plt.subplots(figsize=(24,20))
ax.set_title("Corr Matrix")

mask1 = np.triu(np.ones_like(corr_matrix, dtype=bool))

sn.heatmap(corr_matrix, mask=mask1, annot=True, linewidths=.5, ax=ax)

plt.show()

# %%
plt.figure(figsize=(13,17))
sn.pairplot(data=df)
plt.show()

# %%
bike_2011 = pd.read_csv('2011-capitalbikeshare-tripdata.csv')
bike_2012_q1 = pd.read_csv('2012Q1-capitalbikeshare-tripdata.csv')
bike_2012_q2 = pd.read_csv('2012Q2-capitalbikeshare-tripdata.csv')
bike_2012_q3 = pd.read_csv('2012Q3-capitalbikeshare-tripdata.csv')
bike_2012_q4 = pd.read_csv('2012Q4-capitalbikeshare-tripdata.csv')

# %%
comb = pd.concat([bike_2011, bike_2012_q1, bike_2012_q2, bike_2012_q3, bike_2012_q4], axis=0)
display(comb.head())
comb.dtypes
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      3548  2011-01-01 00:01:29  2011-01-01 01:00:37                 31620
# 1       346  2011-01-01 00:02:46  2011-01-01 00:08:32                 31105
# 2       562  2011-01-01 00:06:13  2011-01-01 00:15:36                 31400
# 3       434  2011-01-01 00:09:21  2011-01-01 00:16:36                 31111
# 4       233  2011-01-01 00:28:26  2011-01-01 00:32:19                 31104
#
#                     Start station  End station number  \
# 0                   5th & F St NW               31620
# 1            14th & Harvard St NW               31101
# 2  Georgia & New Hampshire Ave NW               31104
# 3                  10th & U St NW               31503
# 4     Adams Mill & Columbia Rd NW               31106
#
#                    End station Bike number Member type
# 0                5th & F St NW      W00247      Member
# 1               14th & V St NW      W00675      Casual
# ...

# %%
display(comb.isnull().sum())
# Out:
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# dtype: int64

# %%
start_station = pd.DataFrame(comb.groupby('Start station').size().reset_index(name='Counts'))

display(start_station.head())
# Out:
#                    Start station  Counts
# 0                 10th & E St NW    6280
# 1            10th & Monroe St NE    5423
# 2                 10th & U St NW   38149
# 3  10th St & Constitution Ave NW   33682
# 4                 11th & F St NW      38

# %%
# check that the shape of the start_station dataset is correct
display(start_station.shape)

# check the missing values of the start_station dataset
display(start_station.isnull().sum())

# check the data types of the start_station dataset
display(start_station.dtypes)

# check the unique values of the start_station dataset
display(start_station.nunique())
# Out:
# (194, 2)
# Start station    0
# Counts           0
# dtype: int64
# Start station    object
# Counts            int64
# dtype: object
# Start station    194
# Counts           193
# dtype: int64

# %%
# add two new columns to the start_station dataset called 'Start station latitude' and 'Start station longitude'
start_station['Start station latitude'] = ''
start_station['Start station longitude'] = ''

# check the first 5 rows of the start_station dataset
display(start_station.head())
# Out:
#                    Start station  Counts Start station latitude  \
# 0                 10th & E St NW    6280
# 1            10th & Monroe St NE    5423
# 2                 10th & U St NW   38149
# 3  10th St & Constitution Ave NW   33682
# 4                 11th & F St NW      38
#
#   Start station longitude
# 0
# 1
# 2
# 3
# 4

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import math
import folium
import geopy
from geopy.geocoders import Nominatim
import time
from geopy.exc import GeocoderUnavailable
from geopy.extra.rate_limiter import RateLimiter
import branca.colormap as cm
from folium.plugins import HeatMap
from folium.plugins import HeatMapWithTime

# %%
# use the geolocator to find the latitude and longitude of each start station
geolocator = Nominatim(user_agent="my-geocoding_application", timeout=10)

# create a for loop to iterate through the start_station dataset and find the latitude and longitude of each start station
for i in range(len(start_station)):
    location = geolocator.geocode(start_station['Start station'][i])
    if location is not None:
        start_station['Start station latitude'][i] = location.latitude
        start_station['Start station longitude'][i] = location.longitude

# check the first 5 rows of the start_station dataset
display(start_station.head())

# check the data types of the start_station dataset
display(start_station.dtypes)

# check the missing values of the start_station dataset
display(start_station.isnull().sum())
# Out:
# <ipython-input-68-c5341e9e3358>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   start_station['Start station latitude'][i] = location.latitude
# <ipython-input-68-c5341e9e3358>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   start_station['Start station longitude'][i] = location.longitude
#                    Start station  Counts Start station latitude  \
# 0                 10th & E St NW    6280               8.212298
# 1            10th & Monroe St NE    5423              38.932471
# 2                 10th & U St NW   38149              40.805476
# ...

# %%
start_station.to_csv("start_coord.csv", index=False)

# %%
start_coord = pd.read_csv("start_coord.csv")
display(start_coord.head())
# Out:
#                    Start station  Counts  Start station latitude  \
# 0                 10th & E St NW    6280                8.212298
# 1            10th & Monroe St NE    5423               38.932471
# 2                 10th & U St NW   38149               40.805476
# 3  10th St & Constitution Ave NW   33682               38.891931
# 4                 11th & F St NW      38               38.897342
#
#    Start station longitude
# 0               124.243223
# 1               -76.993355
# 2               -73.856422
# 3               -77.025990
# 4               -77.012052

# %%
start_coord.dtypes
# Out:
# Start station               object
# Counts                       int64
# Start station latitude     float64
# Start station longitude    float64
# dtype: object

# %%
pd.isnull(start_coord).sum()
# Out:
# Start station               0
# Counts                      0
# Start station latitude     21
# Start station longitude    21
# dtype: int64

# %%
# count the unique values of each End stations using groupby
display(comb.groupby('End station').size())

# create a new df with the unique values of each End stations and the count of each End station
end_station = pd.DataFrame(comb.groupby('End station').size().reset_index(name='counts'))

# check the first 5 rows of the End_station dataset
display(end_station.head())
# Out:
# End station
# 10th & E St NW                    6950
# 10th & Monroe St NE               4793
# 10th & U St NW                   39698
# 10th St & Constitution Ave NW    40233
# 11th & F St NW                     693
#                                  ...
# Wilson Blvd & Franklin Rd         2683
# Wilson Blvd & N Edgewood St       2421
# Wilson Blvd & N Quincy St         1650
# Wilson Blvd & N Uhle St           5228
# Wisconsin Ave & Newark St NW      8941
# Length: 194, dtype: int64
#                      End station  counts
# 0                 10th & E St NW    6950
# 1            10th & Monroe St NE    4793
# 2                 10th & U St NW   39698
# 3  10th St & Constitution Ave NW   40233
# 4                 11th & F St NW     693

# %%
# add two new columns to the end_station dataset called 'Start station latitude' and 'Start station longitude'
end_station['End station latitude'] = ''
end_station['End station longitude'] = ''

# check the first 5 rows of the end_station dataset
display(end_station.head())
# Out:
#                      End station  counts End station latitude  \
# 0                 10th & E St NW    6950
# 1            10th & Monroe St NE    4793
# 2                 10th & U St NW   39698
# 3  10th St & Constitution Ave NW   40233
# 4                 11th & F St NW     693
#
#   End station longitude
# 0
# 1
# 2
# 3
# 4

# %%
# use the geolocator to find the latitude and longitude of each End station
geolocator = Nominatim(user_agent="my-geocoding_application", timeout=10)

# create a for loop to iterate through the end_station dataset and find the latitude and longitude of each End station
for i in range(len(end_station)):
    location = geolocator.geocode(end_station['End station'][i])
    if location is not None:
        end_station['End station latitude'][i] = location.latitude
        end_station['End station longitude'][i] = location.longitude

# check the first 5 rows of the end_station dataset
display(end_station.head())

# check the data types of the end_station dataset
display(end_station.dtypes)

# check the missing values of the end_station dataset
display(end_station.isnull().sum())

# check the unique values of the end_station dataset
display(end_station.nunique())
# Out:
# <ipython-input-75-d671c7251a9c>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   end_station['End station latitude'][i] = location.latitude
# <ipython-input-75-d671c7251a9c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   end_station['End station longitude'][i] = location.longitude
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-d671c7251a9c> in <module>
# ...

# %%
start_station.dtypes

# %%
# Create a heatmap layer using the start station coordinates and counts
heat_data = start_coord[['Start station latitude', 'Start station longitude', 'Counts']].values.tolist()
start_station_map = folium.Map(location=[38.9072, -77.0369], zoom_start=12)
HeatMap(heat_data).add_to(start_station_map)

# Add markers to the map with the count number of each start station
for lat, lng, label, count in zip(start_coord['Start station latitude'], start_coord['Start station longitude'], start_coord['Start station'], start_coord['counts']):
    if isinstance(lat, float) and isinstance(lng, float):
        folium.Marker(
            [lat, lng],
            popup=label,
            icon=folium.Icon(color='blue', icon='bicycle', prefix='fa', icon_size=(1,1)),
            tooltip=f"{count} trips"
        ).add_to(start_station_map)

# Display the map
start_station_map
